# %%
import spacy
import en_core_web_md
import pandas as pd
nlp = en_core_web_md.load()
spacy.load('en_core_web_md')

# %%
goog_data = pd.read_csv("googledata.csv")
meta_data = pd.read_csv('metadata.csv')
net_data = pd.read_csv('netflixdata.csv')
app_data = pd.read_csv('appledata.csv')
amaz_data = pd.read_csv('amazondata.csv')

# %%
y1 = "work life balance"
y2 = "culture value"
y3 = "career oppurtunity"
y4 = "company benefit"
y5 = "senior management"
spacydf = goog_data.dropna()

def spacy_score(comment):
    spacy = nlp(comment).similarity(input_comm)
    return spacy

input_comm = nlp(y1)
spacydf['spacy_score_wlb'] = spacydf['Review'].apply(spacy_score)

input_comm = nlp(y2)
spacydf['spacy_score_cv'] = spacydf['Review'].apply(spacy_score)

input_comm = nlp(y3)
spacydf['spacy_score_co'] = spacydf['Review'].apply(spacy_score)

input_comm = nlp(y4)
spacydf['spacy_score_cb'] = spacydf['Review'].apply(spacy_score)

input_comm = nlp(y5)
spacydf['spacy_score_sm'] = spacydf['Review'].apply(spacy_score)
# Out:
# C:\Users\pokem\AppData\Local\Temp\ipykernel_3768\1429628025.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spacydf['spacy_score_wlb'] = spacydf['Review'].apply(spacy_score)
# C:\Users\pokem\AppData\Local\Temp\ipykernel_3768\1429628025.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spacydf['spacy_score_cv'] = spacydf['Review'].apply(spacy_score)
# C:\Users\pokem\AppData\Local\Temp\ipykernel_3768\1429628025.py:19: SettingWithCopyWarning:
# ...

# %%
y1 = "work life balance"
y2 = "culture value"
y3 = "career oppurtunity"
y4 = "company benefit"
y5 = "senior management"
spacydf1 = meta_data.dropna()

def spacy_score(comment):
    spacy = nlp(comment).similarity(input_comm)
    return spacy

input_comm = nlp(y1)
spacydf1['spacy_score_wlb'] = spacydf1['Review'].apply(spacy_score)

input_comm = nlp(y2)
spacydf1['spacy_score_cv'] = spacydf1['Review'].apply(spacy_score)

input_comm = nlp(y3)
spacydf1['spacy_score_co'] = spacydf1['Review'].apply(spacy_score)

input_comm = nlp(y4)
spacydf1['spacy_score_cb'] = spacydf1['Review'].apply(spacy_score)

input_comm = nlp(y5)
spacydf1['spacy_score_sm'] = spacydf1['Review'].apply(spacy_score)

# %%
y1 = "work life balance"
y2 = "culture value"
y3 = "career oppurtunity"
y4 = "company benefit"
y5 = "senior management"
spacydf2 = net_data.dropna()

def spacy_score(comment):
    spacy = nlp(comment).similarity(input_comm)
    return spacy

input_comm = nlp(y1)
spacydf2['spacy_score_wlb'] = spacydf2['Review'].apply(spacy_score)

input_comm = nlp(y2)
spacydf2['spacy_score_cv'] = spacydf2['Review'].apply(spacy_score)

input_comm = nlp(y3)
spacydf2['spacy_score_co'] = spacydf2['Review'].apply(spacy_score)

input_comm = nlp(y4)
spacydf2['spacy_score_cb'] = spacydf2['Review'].apply(spacy_score)

input_comm = nlp(y5)
spacydf2['spacy_score_sm'] = spacydf2['Review'].apply(spacy_score)
# Out:
# C:\Users\pokem\AppData\Local\Temp\ipykernel_3768\3368563713.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spacydf2['spacy_score_wlb'] = spacydf2['Review'].apply(spacy_score)
# C:\Users\pokem\AppData\Local\Temp\ipykernel_3768\3368563713.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spacydf2['spacy_score_cv'] = spacydf2['Review'].apply(spacy_score)
# C:\Users\pokem\AppData\Local\Temp\ipykernel_3768\3368563713.py:19: SettingWithCopyWarning:
# ...

# %%
y1 = "work life balance"
y2 = "culture value"
y3 = "career oppurtunity"
y4 = "company benefit"
y5 = "senior management"
spacydf3 = app_data.dropna()

def spacy_score(comment):
    spacy = nlp(comment).similarity(input_comm)
    return spacy

input_comm = nlp(y1)
spacydf3['spacy_score_wlb'] = spacydf3['Review'].apply(spacy_score)

input_comm = nlp(y2)
spacydf3['spacy_score_cv'] = spacydf3['Review'].apply(spacy_score)

input_comm = nlp(y3)
spacydf3['spacy_score_co'] = spacydf3['Review'].apply(spacy_score)

input_comm = nlp(y4)
spacydf3['spacy_score_cb'] = spacydf3['Review'].apply(spacy_score)

input_comm = nlp(y5)
spacydf3['spacy_score_sm'] = spacydf3['Review'].apply(spacy_score)

# %%
y1 = "work life balance"
y2 = "culture value"
y3 = "career oppurtunity"
y4 = "company benefit"
y5 = "senior management"
spacydf4 = amaz_data.dropna()

def spacy_score(comment):
    spacy = nlp(comment).similarity(input_comm)
    return spacy

input_comm = nlp(y1)
spacydf4['spacy_score_wlb'] = spacydf4['Review'].apply(spacy_score)

input_comm = nlp(y2)
spacydf4['spacy_score_cv'] = spacydf4['Review'].apply(spacy_score)

input_comm = nlp(y3)
spacydf4['spacy_score_co'] = spacydf4['Review'].apply(spacy_score)

input_comm = nlp(y4)
spacydf4['spacy_score_cb'] = spacydf4['Review'].apply(spacy_score)

input_comm = nlp(y5)
spacydf4['spacy_score_sm'] = spacydf4['Review'].apply(spacy_score)
# Out:
# C:\Users\pokem\AppData\Local\Temp\ipykernel_3768\38915689.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spacydf4['spacy_score_wlb'] = spacydf4['Review'].apply(spacy_score)
# C:\Users\pokem\AppData\Local\Temp\ipykernel_3768\38915689.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spacydf4['spacy_score_cv'] = spacydf4['Review'].apply(spacy_score)
# C:\Users\pokem\AppData\Local\Temp\ipykernel_3768\38915689.py:19: SettingWithCopyWarning:
# ...

# %%
spacydf['spacy_score_wlb'].mean()
spacydf['spacy_score_cv'].mean()
spacydf['spacy_score_co'].mean()
spacydf['spacy_score_cb'].mean()
spacydf['spacy_score_sm'].mean()

d = {'Work Life Balance': [spacydf['spacy_score_wlb'].mean(), spacydf1['spacy_score_wlb'].mean(), spacydf2['spacy_score_wlb'].mean(), spacydf3['spacy_score_wlb'].mean(), spacydf4['spacy_score_wlb'].mean()], 
     'Culture Value': [spacydf['spacy_score_cv'].mean(), spacydf1['spacy_score_cv'].mean(), spacydf2['spacy_score_cv'].mean(), spacydf3['spacy_score_cv'].mean(), spacydf4['spacy_score_cv'].mean()],
     'Career Oppurtunity': [spacydf['spacy_score_co'].mean(), spacydf1['spacy_score_co'].mean(), spacydf2['spacy_score_co'].mean(), spacydf3['spacy_score_co'].mean(), spacydf4['spacy_score_co'].mean()],
     'Company Benefit': [spacydf['spacy_score_cb'].mean(), spacydf1['spacy_score_cb'].mean(), spacydf2['spacy_score_cb'].mean(), spacydf3['spacy_score_cb'].mean(), spacydf4['spacy_score_cb'].mean()],
     'Senior Management': [spacydf['spacy_score_sm'].mean(), spacydf1['spacy_score_sm'].mean(), spacydf2['spacy_score_sm'].mean(), spacydf3['spacy_score_sm'].mean(), spacydf4['spacy_score_sm'].mean()]}
spacyfinal = pd.DataFrame(data=d, index=["Google", "Meta", "Netflix", "Apple", "Amazon"])

spacyfinal
# Out:
#          Work Life Balance  Culture Value  Career Oppurtunity  \
# Google            0.658756       0.562950            0.500987
# Meta              0.684144       0.589222            0.519926
# Netflix           0.661227       0.559332            0.505134
# Apple             0.684518       0.581586            0.514938
# Amazon            0.665884       0.550047            0.487546
#
#          Company Benefit  Senior Management
# Google          0.590444           0.457118
# Meta            0.613555           0.478655
# Netflix         0.592199           0.454567
# Apple           0.613680           0.457737
# Amazon          0.581267           0.414165

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

sentiment = SentimentIntensityAnalyzer()
def get_sentiment(review, **kwargs):
    sentiment_score = sentiment.polarity_scores(review)
    positive_meter = round((sentiment_score['pos'] * 100), 2)
    negative_meter = round((sentiment_score['neg'] * 100), 2)
    return positive_meter if kwargs['k'] == 'positive' else negative_meter

sentimentdf = goog_data.dropna()
sentimentdf['positive_sentiment_score'] = sentimentdf['Review'].apply(get_sentiment, k='positive')
sentimentdf['negative_sentiment_score'] = sentimentdf['Review'].apply(get_sentiment, k='negative')
# Out:
# C:\Users\pokem\AppData\Local\Temp\ipykernel_3768\2202138962.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sentimentdf['positive_sentiment_score'] = sentimentdf['Review'].apply(get_sentiment, k='positive')
# C:\Users\pokem\AppData\Local\Temp\ipykernel_3768\2202138962.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sentimentdf['negative_sentiment_score'] = sentimentdf['Review'].apply(get_sentiment, k='negative')

# %%
sentimentdf1 = meta_data.dropna()
sentimentdf1['positive_sentiment_score'] = sentimentdf1['Review'].apply(get_sentiment, k='positive')
sentimentdf1['negative_sentiment_score'] = sentimentdf1['Review'].apply(get_sentiment, k='negative')

# %%
sentimentdf2 = net_data.dropna()
sentimentdf2['positive_sentiment_score'] = sentimentdf2['Review'].apply(get_sentiment, k='positive')
sentimentdf2['negative_sentiment_score'] = sentimentdf2['Review'].apply(get_sentiment, k='negative')
# Out:
# C:\Users\pokem\AppData\Local\Temp\ipykernel_3768\3440685398.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sentimentdf2['positive_sentiment_score'] = sentimentdf2['Review'].apply(get_sentiment, k='positive')
# C:\Users\pokem\AppData\Local\Temp\ipykernel_3768\3440685398.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sentimentdf2['negative_sentiment_score'] = sentimentdf2['Review'].apply(get_sentiment, k='negative')

# %%
sentimentdf3 = app_data.dropna()
sentimentdf3['positive_sentiment_score'] = sentimentdf3['Review'].apply(get_sentiment, k='positive')
sentimentdf3['negative_sentiment_score'] = sentimentdf3['Review'].apply(get_sentiment, k='negative')

# %%
sentimentdf4 = amaz_data.dropna()
sentimentdf4['positive_sentiment_score'] = sentimentdf4['Review'].apply(get_sentiment, k='positive')
sentimentdf4['negative_sentiment_score'] = sentimentdf4['Review'].apply(get_sentiment, k='negative')
# Out:
# C:\Users\pokem\AppData\Local\Temp\ipykernel_3768\1828279766.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sentimentdf4['positive_sentiment_score'] = sentimentdf4['Review'].apply(get_sentiment, k='positive')
# C:\Users\pokem\AppData\Local\Temp\ipykernel_3768\1828279766.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sentimentdf4['negative_sentiment_score'] = sentimentdf4['Review'].apply(get_sentiment, k='negative')

# %%
spacyfinal
# Out:
#          Work Life Balance  Culture Value  Career Oppurtunity  \
# Google            0.658756       0.562950            0.500987
# Meta              0.684144       0.589222            0.519926
# Netflix           0.661227       0.559332            0.505134
# Apple             0.684518       0.581586            0.514938
# Amazon            0.665884       0.550047            0.487546
#
#          Company Benefit  Senior Management
# Google          0.590444           0.457118
# Meta            0.613555           0.478655
# Netflix         0.592199           0.454567
# Apple           0.613680           0.457737
# Amazon          0.581267           0.414165

# %%
senfinal = spacyfinal.mul([(sentimentdf['positive_sentiment_score'].mean() - sentimentdf['positive_sentiment_score'].min())/(sentimentdf['positive_sentiment_score'].max() - sentimentdf['positive_sentiment_score'].min()), (sentimentdf1['positive_sentiment_score'].mean() - sentimentdf1['positive_sentiment_score'].min())/(sentimentdf1['positive_sentiment_score'].max() - sentimentdf1['positive_sentiment_score'].min()), (sentimentdf2['positive_sentiment_score'].mean() - sentimentdf2['positive_sentiment_score'].min())/(sentimentdf2['positive_sentiment_score'].max() - sentimentdf2['positive_sentiment_score'].min()), (sentimentdf3['positive_sentiment_score'].mean() - sentimentdf3['positive_sentiment_score'].min())/(sentimentdf3['positive_sentiment_score'].max() - sentimentdf3['positive_sentiment_score'].min()), (sentimentdf4['positive_sentiment_score'].mean() - sentimentdf4['positive_sentiment_score'].min())/(sentimentdf4['positive_sentiment_score'].max() - sentimentdf4['positive_sentiment_score'].min())], axis=0)
senfinal
# Out:
#          Work Life Balance  Culture Value  Career Oppurtunity  \
# Google            0.164987       0.140992            0.125473
# Meta              0.250299       0.215571            0.190219
# Netflix           0.185798       0.157167            0.141937
# Apple             0.248214       0.210889            0.186722
# Amazon            0.169106       0.139689            0.123816
#
#          Company Benefit  Senior Management
# Google          0.147878           0.114486
# Meta            0.224474           0.175119
# Netflix         0.166402           0.127729
# Apple           0.222527           0.165980
# Amazon          0.147617           0.105180
